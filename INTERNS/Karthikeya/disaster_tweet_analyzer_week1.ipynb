# %% [markdown]
# # Disaster Tweet Analyzer: NLP for Crisis Communication
# ### Week 1 Progress
#
# ### Project Goals
# 1. Analyzing disaster tweets.
# 2. Utilizing Natural Language Processing (NLP) techniques to classify tweets.
# 3. Developing a system to assist in crisis communication through social media analysis.

# %% [markdown]
# ### Dataset
# - Dataset: [Disaster Tweets Dataset](https://www.kaggle.com/datasets/vstepanenko/disaster-tweets/data)
# - Status: Successfully downloaded and verified.

# %% [markdown]
# ### Initial Exploration of the Dataset
# 1. Loading the dataset and displaying the first few rows.
# 2. Analyzing the dataset.

# %%
# Import necessary libraries
import pandas as pd

# Load the dataset
file_path = 'disaster_tweets.csv'  # Replace with your file path
tweets_df = pd.read_csv('/Users/karthik/Downloads/infosys/tweets.csv')

# Display the first few rows of the dataset
tweets_df.head(15)
# Out:
#     id keyword         location  \
# 0    0  ablaze              NaN
# 1    1  ablaze              NaN
# 2    2  ablaze    New York City
# 3    3  ablaze   Morgantown, WV
# 4    4  ablaze              NaN
# 5    5  ablaze               OC
# 6    6  ablaze  London, England
# 7    7  ablaze           Bharat
# 8    8  ablaze     Accra, Ghana
# 9    9  ablaze        Searching
# 10  10  ablaze              NaN
# 11  11  ablaze              NaN
# 12  12  ablaze              NaN
# 13  13  ablaze        HYDERABAD
# 14  14  ablaze         Reno, NV
#
#                                                  text  target
# 0   Communal violence in Bhainsa, Telangana. "Ston...       1
# 1   Telangana: Section 144 has been imposed in Bha...       1
# 2   Arsonist sets cars ablaze at dealership https:...       1
# 3   Arsonist sets cars ablaze at dealership https:...       1
# 4   "Lord Jesus, your love brings freedom and pard...       0
# 5   If this child was Chinese, this tweet would ha...       0
# ...

# %% [markdown]
# ### Basic Text Preprocessing Steps
# - Handle missing values.
# - Clean up the raw tweet text (remove links, special characters, etc.).

# %%
# Check for missing values
missing_values = tweets_df.isnull().sum()
missing_values

# Basic text cleanup function
import re

def clean_tweet(text):
    # Remove links, special characters, and extra spaces
    text = re.sub(r'http\S+|www\S+', '', text)  # Remove URLs
    text = re.sub(r'[^A-Za-z0-9]+', ' ', text)  # Remove special characters
    text = text.strip()  # Remove leading and trailing spaces
    return text

# Apply the cleanup function to the tweet text
tweets_df['cleaned_text'] = tweets_df['text'].apply(clean_tweet)

# Display the cleaned text
tweets_df[['text', 'cleaned_text']].head(15)
# Out:
#                                                  text  \
# 0   Communal violence in Bhainsa, Telangana. "Ston...
# 1   Telangana: Section 144 has been imposed in Bha...
# 2   Arsonist sets cars ablaze at dealership https:...
# 3   Arsonist sets cars ablaze at dealership https:...
# 4   "Lord Jesus, your love brings freedom and pard...
# 5   If this child was Chinese, this tweet would ha...
# 6   Several houses have been set ablaze in Ngemsib...
# 7   Asansol: A BJP office in Salanpur village was ...
# 8   National Security Minister, Kan Dapaah's side ...
# 9   This creature who’s soul is no longer clarent ...
# 10  Images showing the havoc caused by the #Camero...
# 11  Social media went bananas after Chuba Hubbard ...
# 12  Hausa youths set Area Office of Apapa-Iganmu L...
# 13  Under #MamataBanerjee political violence &amp;...
# 14  AMEN! Set the whole system ablaze, man. https:...
#
#                                          cleaned_text
# ...

# %% [markdown]
# ### Week 1 progress
# - Dataset confirmation and verified.
# - Initial exploration completed, and basic text preprocessing steps initiated.
